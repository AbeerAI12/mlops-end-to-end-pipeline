# %%
import pandas as pd
import pickle
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# قراءة بيانات التدريب والاختبار الجاهزة
train_df = pd.read_parquet('train.parquet')
test_df = pd.read_parquet('test.parquet')

print("تم تحميل بيانات التدريب والاختبار بنجاح.")
print("حجم بيانات التدريب:", train_df.shape)
print("حجم بيانات الاختبار:", test_df.shape)
# Out:
# تم تحميل بيانات التدريب والاختبار بنجاح.
# حجم بيانات التدريب: (59664, 17)
# حجم بيانات الاختبار: (19889, 17)
